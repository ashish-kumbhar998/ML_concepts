# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv

x = []
y = []
  
with open('test_data.csv','r') as csvfile:
    df = pd.read_csv('test_data.csv')
    print(df)
    lines = csv.reader(csvfile, delimiter = ',')
    print(plots)
    
    for row in lines:
        x.append(row[1])
        y.append(row[3])
        
plt.bar(x, y, color = 'g', width = 0.72)
plt.title('Matplotlib', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
#    emp id emp name  salary  Age Gender  join year
# 0     101        A   10000   21      M       2020
# 1     102        B   15000   25      F       2019
# 2     103        C    8000   20      F       2022
# 3     202        D    9500   19      F       2022
# 4     201       E     5000   20      M       2022
# 5     202        F   12400   21      M       2021
# 6     203        G   13000   22      M       2020
# 7     301        H   10500   21      M       2020
# <_csv.reader object at 0x7f06c54fd890>

# %%
df = pd.read_csv('test_data.csv')
print(df)

x = list(df.iloc[:,1])
y = list(df.iloc[:,2])
  
plt.bar(x, y)
plt.title('Matplotlib', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
#    emp id emp name  salary  Age Gender  join year
# 0     101        A   10000   21      M       2020
# 1     102        B   15000   25      F       2019
# 2     103        C    8000   20      F       2022
# 3     202        D    9500   19      F       2022
# 4     201       E     5000   20      M       2022
# 5     202        F   12400   21      M       2021
# 6     203        G   13000   22      M       2020
# 7     301        H   10500   21      M       2020

# %%
df = pd.read_csv('test_data.csv')
print(df)

x = list(df.iloc[:,1])
y = list(df.iloc[:,2])

plt.scatter(x, y, color = 'r',s = 100)
plt.title('Matplotlib', fontsize = 20)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
#    emp id emp name  salary  Age Gender  join year
# 0     101        A   10000   21      M       2020
# 1     102        B   15000   25      F       2019
# 2     103        C    8000   20      F       2022
# 3     202        D    9500   19      F       2022
# 4     201       E     5000   20      M       2022
# 5     202        F   12400   21      M       2021
# 6     203        G   13000   22      M       2020
# 7     301        H   10500   21      M       2020

# %%
df = pd.read_csv('test_data.csv')
print(df)

x = list(df.iloc[:,1])
y = list(df.iloc[:,2])

# plt.pie(x,y,autopct = '%.2f%%')
plt.pie(y,labels = x,autopct = '%.2f%%')
plt.title('Matplotlib', fontsize = 20)
plt.show()
# Out:
#    emp id emp name  salary  Age Gender  join year
# 0     101        A   10000   21      M       2020
# 1     102        B   15000   25      F       2019
# 2     103        C    8000   20      F       2022
# 3     202        D    9500   19      F       2022
# 4     201       E     5000   20      M       2022
# 5     202        F   12400   21      M       2021
# 6     203        G   13000   22      M       2020
# 7     301        H   10500   21      M       2020

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)
       }
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
